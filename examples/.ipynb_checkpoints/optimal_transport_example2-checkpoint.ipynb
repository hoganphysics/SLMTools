# %%
# cd("z:\\home\\Vandy\\code\\julia\\SLMTools\\examples")
cd("z:\\home\\Vandy\\code\\julia")
# using SLMTools
using Pkg
println("Current environment path: ", Pkg.project().path)
Pkg.activate("C:\\Users\\micha\\.julia\\environments\\v1.9\\Project.toml")
println("Current environment path: ", Pkg.project().path)
# Out:
# Current environment path: \\srsrv1\lab\home\Vandy\code\julia\SLMTools\Project.toml
# Current environment path: C:\Users\micha\.julia\environments\v1.9\Project.toml
#   Activating project at `C:\Users\micha\.julia\environments\v1.9`

# %%
using SLMTools, Images, Statistics, Plots
N = 1024
NSLM = 1024
sz = (10, 10)
sigma = 0.5
beam0 = lfGaussian(Intensity, (N, N), 5.0)
dsbeam0 = downsample(beam0, 8) # Make a 8x downsampled image
p1 = look(dsbeam0)
# Out:
# 128×128 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(4.10795e-5)   …  Gray{Float64}(4.19028e-5)
#  Gray{Float64}(4.80944e-5)      Gray{Float64}(4.90583e-5)
#  Gray{Float64}(5.61666e-5)      Gray{Float64}(5.72923e-5)
#  Gray{Float64}(6.54299e-5)      Gray{Float64}(6.67412e-5)
#  Gray{Float64}(7.60306e-5)      Gray{Float64}(7.75544e-5)
#  Gray{Float64}(8.81281e-5)   …  Gray{Float64}(8.98944e-5)
#  Gray{Float64}(0.000101895)     Gray{Float64}(0.000103938)
#  Gray{Float64}(0.000117519)     Gray{Float64}(0.000119875)
#  Gray{Float64}(0.000135201)     Gray{Float64}(0.00013791)
#  Gray{Float64}(0.000155154)     Gray{Float64}(0.000158263)
#  Gray{Float64}(0.000177607)  …  Gray{Float64}(0.000181167)
#  Gray{Float64}(0.000202802)     Gray{Float64}(0.000206866)
#  Gray{Float64}(0.000230993)     Gray{Float64}(0.000235622)
#  ⋮                           ⋱
#  Gray{Float64}(0.000206156)     Gray{Float64}(0.000210288)
#  Gray{Float64}(0.000180601)     Gray{Float64}(0.000184221)
#  Gray{Float64}(0.000157819)     Gray{Float64}(0.000160982)
#  Gray{Float64}(0.000137566)     Gray{Float64}(0.000140323)
#  Gray{Float64}(0.000119613)  …  Gray{Float64}(0.00012201)
#  Gray{Float64}(0.000103743)     Gray{Float64}(0.000105822)
#  Gray{Float64}(8.9754e-5)       Gray{Float64}(9.15529e-5)
#  Gray{Float64}(7.74575e-5)      Gray{Float64}(7.90099e-5)
#  Gray{Float64}(6.66787e-5)      Gray{Float64}(6.80151e-5)
#  Gray{Float64}(5.72565e-5)   …  Gray{Float64}(5.84041e-5)
#  Gray{Float64}(4.9043e-5)       Gray{Float64}(5.00259e-5)
#  Gray{Float64}(4.19028e-5)      Gray{Float64}(4.27427e-5)

# %%
target = lfRing(Intensity, (N, N), 3.5, 1.75)
p2 = look(target)
dstarget = downsample(target, 8)
p3 = look(dstarget)
# Out:
# 128×128 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(2.99646e-26)  …  Gray{Float64}(3.43557e-26)
#  Gray{Float64}(8.87469e-26)     Gray{Float64}(1.01732e-25)
#  Gray{Float64}(2.57951e-25)     Gray{Float64}(2.95632e-25)
#  Gray{Float64}(7.35835e-25)     Gray{Float64}(8.43155e-25)
#  Gray{Float64}(2.06016e-24)     Gray{Float64}(2.36015e-24)
#  Gray{Float64}(5.66133e-24)  …  Gray{Float64}(6.48437e-24)
#  Gray{Float64}(1.52703e-23)     Gray{Float64}(1.74867e-23)
#  Gray{Float64}(4.04306e-23)     Gray{Float64}(4.62892e-23)
#  Gray{Float64}(1.05081e-22)     Gray{Float64}(1.20282e-22)
#  Gray{Float64}(2.68106e-22)     Gray{Float64}(3.06827e-22)
#  Gray{Float64}(6.7155e-22)   …  Gray{Float64}(7.68376e-22)
#  Gray{Float64}(1.65143e-21)     Gray{Float64}(1.88914e-21)
#  Gray{Float64}(3.98725e-21)     Gray{Float64}(4.5602e-21)
#  ⋮                           ⋱
#  Gray{Float64}(1.84564e-21)     Gray{Float64}(2.11125e-21)
#  Gray{Float64}(7.52251e-22)     Gray{Float64}(8.6069e-22)
#  Gray{Float64}(3.01016e-22)     Gray{Float64}(3.44481e-22)
#  Gray{Float64}(1.18252e-22)     Gray{Float64}(1.35356e-22)
#  Gray{Float64}(4.56039e-23)  …  Gray{Float64}(5.22107e-23)
#  Gray{Float64}(1.72642e-23)     Gray{Float64}(1.97695e-23)
#  Gray{Float64}(6.41544e-24)     Gray{Float64}(7.34792e-24)
#  Gray{Float64}(2.34003e-24)     Gray{Float64}(2.6807e-24)
#  Gray{Float64}(8.3775e-25)      Gray{Float64}(9.5991e-25)
#  Gray{Float64}(2.94365e-25)  …  Gray{Float64}(3.37358e-25)
#  Gray{Float64}(1.01513e-25)     Gray{Float64}(1.16363e-25)
#  Gray{Float64}(3.43557e-26)     Gray{Float64}(3.93891e-26)

# %%
typeof(dstarget)
# Out:
# LatticeField{Intensity, Float64, 2}

# %%
size(dstarget)
# Out:
# LatticeField{Intensity, Float64, 2}
# Lattice: (-15.890625:0.25:15.859375, -15.890625:0.25:15.859375)
# 128×128 Matrix{Float64}:
#  2.99646e-26  8.87469e-26  2.57951e-25  …  1.01513e-25  3.43557e-26
#  8.87469e-26  2.62423e-25  7.61524e-25     3.00112e-25  1.01732e-25
#  2.57951e-25  7.61524e-25  2.20627e-24     8.70717e-25  2.95632e-25
#  7.35834e-25  2.16881e-24  6.27312e-24     2.47928e-24  8.43155e-25
#  2.06016e-24  6.06221e-24  1.75055e-23     6.92861e-24  2.36015e-24
#  5.66133e-24  1.66315e-23  4.7946e-23   …  1.90045e-23  6.48437e-24
#  1.52703e-23  4.47857e-23  1.28894e-22     5.11651e-23  1.74867e-23
#  4.04306e-23  1.18379e-22  3.40123e-22     1.35213e-22  4.62892e-23
#  1.05081e-22  3.07156e-22  8.81009e-22     3.5076e-22   1.20282e-22
#  2.68106e-22  7.82361e-22  2.2402e-21      8.93235e-22  3.06827e-22
#  6.7155e-22   1.95633e-21  5.59209e-21  …  2.2331e-21   7.68376e-22
#  1.65143e-21  4.80266e-21  1.37045e-20     5.48093e-21  1.88914e-21
#  3.98725e-21  1.15758e-20  3.29745e-20     1.32077e-20  4.5602e-21
#  ⋮                                      ⋱
#  1.84564e-21  5.36631e-21  1.53096e-20     6.12403e-21  2.11125e-21
#  7.52251e-22  2.19095e-21  6.26141e-21     2.50085e-21  8.60689e-22
#  3.01016e-22  8.78211e-22  2.51412e-21     1.00264e-21  3.44481e-22
#  1.18252e-22  3.45584e-22  9.91021e-22     3.94633e-22  1.35356e-22
#  4.56039e-23  1.33498e-22  3.83481e-22  …  1.52478e-22  5.22107e-23
#  1.72642e-23  5.0623e-23   1.45663e-22     5.78324e-23  1.97695e-23
#  6.41544e-24  1.8843e-23   5.431e-23       2.15309e-23  7.34792e-24
#  2.34003e-24  6.88433e-24  1.98754e-23     7.86802e-24  2.6807e-24
#  8.37749e-25  2.46869e-24  7.13904e-24     2.82202e-24  9.59909e-25
#  2.94365e-25  8.68852e-25  2.51671e-24  …  9.93409e-25  3.37358e-25
#  1.01513e-25  3.00112e-25  8.70717e-25     3.43205e-25  1.16363e-25
#  3.43557e-26  1.01732e-25  2.95632e-25     1.16363e-25  3.93891e-26

# %%
phi1 = otPhase(dsbeam0, dstarget, 0.0005);

# %%
phi_big = upsample(phi1,beam0.L);

# %%
look(phi_big)
# Out:
# 1024×1024 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.000375301)  …  Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)  …  Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)  …  Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  ⋮                           ⋱
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)  …  Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)  …  Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)
#  Gray{Float64}(0.000375301)     Gray{Float64}(0.000375301)

# %%
look(phi1)
# Out:
# 128×128 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.311322)   …  Gray{Float64}(0.348352)
#  Gray{Float64}(0.313627)      Gray{Float64}(0.350204)
#  Gray{Float64}(0.371867)      Gray{Float64}(0.407989)
#  Gray{Float64}(0.478935)      Gray{Float64}(0.514602)
#  Gray{Float64}(0.629752)      Gray{Float64}(0.664963)
#  Gray{Float64}(0.820612)   …  Gray{Float64}(0.855367)
#  Gray{Float64}(0.0487738)     Gray{Float64}(0.0830726)
#  Gray{Float64}(0.312179)      Gray{Float64}(0.346021)
#  Gray{Float64}(0.609269)      Gray{Float64}(0.642655)
#  Gray{Float64}(0.938857)      Gray{Float64}(0.971787)
#  Gray{Float64}(0.300034)   …  Gray{Float64}(0.332507)
#  Gray{Float64}(0.692103)      Gray{Float64}(0.724121)
#  Gray{Float64}(0.114532)      Gray{Float64}(0.146093)
#  ⋮                         ⋱
#  Gray{Float64}(0.102439)      Gray{Float64}(0.134857)
#  Gray{Float64}(0.738027)      Gray{Float64}(0.770903)
#  Gray{Float64}(0.405234)      Gray{Float64}(0.438566)
#  Gray{Float64}(0.104971)      Gray{Float64}(0.138759)
#  Gray{Float64}(0.838426)   …  Gray{Float64}(0.872671)
#  Gray{Float64}(0.607163)      Gray{Float64}(0.641865)
#  Gray{Float64}(0.413243)      Gray{Float64}(0.448401)
#  Gray{Float64}(0.259416)      Gray{Float64}(0.29503)
#  Gray{Float64}(0.149395)      Gray{Float64}(0.185464)
#  Gray{Float64}(0.0882723)  …  Gray{Float64}(0.124796)
#  Gray{Float64}(0.0831727)     Gray{Float64}(0.120151)
#  Gray{Float64}(0.144276)      Gray{Float64}(0.181707)

# %%
sqrt(dsbeam0) * phi1 |> look
# Out:
# 128×256 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.00640933)  …  Gray{Float64}(0.848352)
#  Gray{Float64}(0.00693502)     Gray{Float64}(0.850204)
#  Gray{Float64}(0.00749444)     Gray{Float64}(0.907989)
#  Gray{Float64}(0.00808887)     Gray{Float64}(0.0146018)
#  Gray{Float64}(0.00871955)     Gray{Float64}(0.164963)
#  Gray{Float64}(0.00938766)  …  Gray{Float64}(0.355367)
#  Gray{Float64}(0.0100943)      Gray{Float64}(0.583073)
#  Gray{Float64}(0.0108406)      Gray{Float64}(0.846021)
#  Gray{Float64}(0.0116276)      Gray{Float64}(0.142655)
#  Gray{Float64}(0.0124561)      Gray{Float64}(0.471787)
#  Gray{Float64}(0.0133269)   …  Gray{Float64}(0.832507)
#  Gray{Float64}(0.0142408)      Gray{Float64}(0.224121)
#  Gray{Float64}(0.0151984)      Gray{Float64}(0.646093)
#  ⋮                          ⋱  ⋮
#  Gray{Float64}(0.0143581)      Gray{Float64}(0.634857)
#  Gray{Float64}(0.0134388)      Gray{Float64}(0.270903)
#  Gray{Float64}(0.0125626)      Gray{Float64}(0.938566)
#  Gray{Float64}(0.0117289)      Gray{Float64}(0.638759)
#  Gray{Float64}(0.0109368)   …  Gray{Float64}(0.372671)
#  Gray{Float64}(0.0101854)      Gray{Float64}(0.141865)
#  Gray{Float64}(0.00947386)     Gray{Float64}(0.948401)
#  Gray{Float64}(0.00880099)     Gray{Float64}(0.79503)
#  Gray{Float64}(0.0081657)      Gray{Float64}(0.685464)
#  Gray{Float64}(0.0075668)   …  Gray{Float64}(0.624796)
#  Gray{Float64}(0.00700307)     Gray{Float64}(0.620151)
#  Gray{Float64}(0.00647324)     Gray{Float64}(0.681707)

# %%
look(square(sft(sqrt(beam0) * phi_big)),target)
# Out:
# 1024×2048 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(3.09243e-13)  …  Gray{Float64}(1.31409e-26)
#  Gray{Float64}(2.82599e-13)     Gray{Float64}(1.5083e-26)
#  Gray{Float64}(2.5686e-13)      Gray{Float64}(1.73071e-26)
#  Gray{Float64}(2.32082e-13)     Gray{Float64}(1.98532e-26)
#  Gray{Float64}(2.08322e-13)     Gray{Float64}(2.27673e-26)
#  Gray{Float64}(1.85635e-13)  …  Gray{Float64}(2.61014e-26)
#  Gray{Float64}(1.64071e-13)     Gray{Float64}(2.99149e-26)
#  Gray{Float64}(1.4368e-13)      Gray{Float64}(3.42756e-26)
#  Gray{Float64}(1.24509e-13)     Gray{Float64}(3.92604e-26)
#  Gray{Float64}(1.06602e-13)     Gray{Float64}(4.49569e-26)
#  Gray{Float64}(9.00014e-14)  …  Gray{Float64}(5.14648e-26)
#  Gray{Float64}(7.47456e-14)     Gray{Float64}(5.88976e-26)
#  Gray{Float64}(6.0871e-14)      Gray{Float64}(6.7384e-26)
#  ⋮                           ⋱
#  Gray{Float64}(6.76149e-13)     Gray{Float64}(6.7384e-26)
#  Gray{Float64}(6.43742e-13)     Gray{Float64}(5.88976e-26)
#  Gray{Float64}(6.11434e-13)     Gray{Float64}(5.14648e-26)
#  Gray{Float64}(5.79295e-13)  …  Gray{Float64}(4.49569e-26)
#  Gray{Float64}(5.47399e-13)     Gray{Float64}(3.92604e-26)
#  Gray{Float64}(5.15814e-13)     Gray{Float64}(3.42756e-26)
#  Gray{Float64}(4.84612e-13)     Gray{Float64}(2.99149e-26)
#  Gray{Float64}(4.53861e-13)     Gray{Float64}(2.61014e-26)
#  Gray{Float64}(4.23631e-13)  …  Gray{Float64}(2.27673e-26)
#  Gray{Float64}(3.93989e-13)     Gray{Float64}(1.98532e-26)
#  Gray{Float64}(3.65e-13)        Gray{Float64}(1.73071e-26)
#  Gray{Float64}(3.3673e-13)      Gray{Float64}(1.5083e-26)

# %%
phi3 = gs(beam0,target,100,phi_big);

# %%
typeof(phi3)
# Out:
# LatticeField{ComplexPhase, ComplexF64, 2}

# %%
square(sft(sqrt(beam0) * phi3)) |> look
# Out:
# 1024×1024 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(2.428e-7)    …  Gray{Float64}(4.78685e-7)
#  Gray{Float64}(6.94602e-8)     Gray{Float64}(5.69932e-8)
#  Gray{Float64}(1.291e-8)       Gray{Float64}(2.94751e-7)
#  Gray{Float64}(1.6361e-7)      Gray{Float64}(1.39046e-6)
#  Gray{Float64}(4.17062e-7)     Gray{Float64}(3.71481e-7)
#  Gray{Float64}(3.34774e-7)  …  Gray{Float64}(1.09977e-6)
#  Gray{Float64}(1.45832e-7)     Gray{Float64}(2.82321e-7)
#  Gray{Float64}(5.15547e-7)     Gray{Float64}(1.13309e-6)
#  Gray{Float64}(1.75343e-7)     Gray{Float64}(5.91673e-7)
#  Gray{Float64}(6.89044e-7)     Gray{Float64}(1.85986e-8)
#  Gray{Float64}(1.66715e-7)  …  Gray{Float64}(4.17114e-7)
#  Gray{Float64}(1.2937e-7)      Gray{Float64}(5.58375e-7)
#  Gray{Float64}(2.08419e-7)     Gray{Float64}(1.62899e-8)
#  ⋮                          ⋱
#  Gray{Float64}(3.26042e-7)     Gray{Float64}(2.89252e-7)
#  Gray{Float64}(5.77427e-9)     Gray{Float64}(7.82294e-7)
#  Gray{Float64}(2.85859e-7)     Gray{Float64}(7.89163e-8)
#  Gray{Float64}(4.18424e-7)  …  Gray{Float64}(6.67882e-7)
#  Gray{Float64}(1.35287e-7)     Gray{Float64}(3.91508e-7)
#  Gray{Float64}(1.66263e-7)     Gray{Float64}(7.11589e-7)
#  Gray{Float64}(3.62688e-7)     Gray{Float64}(1.69607e-7)
#  Gray{Float64}(3.61254e-7)     Gray{Float64}(4.37527e-7)
#  Gray{Float64}(4.90482e-9)  …  Gray{Float64}(5.26907e-7)
#  Gray{Float64}(8.8161e-7)      Gray{Float64}(4.58414e-7)
#  Gray{Float64}(1.46406e-7)     Gray{Float64}(4.45907e-7)
#  Gray{Float64}(3.39398e-8)     Gray{Float64}(3.12515e-7)

# %%
typeof(target)
# Out:
# LatticeField{Intensity, Float64, 2}

# %%
heatmap(normalizeLF(square(sft(sqrt(beam0) * phi3))).data .- normalizeLF(target).data)

# %%
(normalizeLF((normalizeLF(square(sft(sqrt(beam0) * phi3))).data .- normalizeLF(target).data) .- normalizeLF(target).data)[600,:] |> maximum
# Out:
# 8.134723896596587e-7

# %%
(normalizeLF(square(sft(sqrt(beam0) * phi3))).data) |> maximum
# Out:
# 1.095939283952382e-5

# %%
plot([(normalizeLF(square(sft(sqrt(beam0) * phi3))).data)[550,:], (normalizeLF(target).data)[550,:] ])

# %%
SchroffError(downsample(target,4), downsample(square(sft(sqrt(beam0) * phi3)), 4), 0.5)
# Out:
# 0.03226776597559669

# %%
L = natlat((128, 128))
phi1 = otPhase(dsbeam0, dstarget, 0.0005)
beam_out = sft(sqrt(dsbeam0) * wrap(phi1)) .^ 2 |> nabs;
beam0_out = sft(sqrt.(dsbeam0.data) .* exp.(0*2pi * im * phi1.data)) .^ 2 |> nabs;
LFout = LatticeField{Intensity}(beam_out, dsbeam0.L);
LF0out = LatticeField{Intensity}(beam0_out, dsbeam0.L);
# p7 = look(dsbeam0, LF0out, dstarget, phi1, LFout)
# Out:
# 128×128 Matrix{Float64}:
#  9.18699e-22  9.54692e-22  1.0631e-21   …  1.0631e-21   9.54692e-22
#  9.54691e-22  9.92094e-22  1.10475e-21     1.10475e-21  9.92094e-22
#  1.0631e-21   1.10475e-21  1.23019e-21     1.23019e-21  1.10475e-21
#  1.24522e-21  1.294e-21    1.44094e-21     1.44094e-21  1.294e-21
#  1.50324e-21  1.56214e-21  1.73952e-21     1.73952e-21  1.56214e-21
#  1.8403e-21   1.9124e-21   2.12955e-21  …  2.12955e-21  1.9124e-21
#  2.2605e-21   2.34906e-21  2.6158e-21      2.6158e-21   2.34906e-21
#  2.76903e-21  2.87751e-21  3.20426e-21     3.20426e-21  2.87751e-21
#  3.37226e-21  3.50438e-21  3.90231e-21     3.90231e-21  3.50438e-21
#  4.07784e-21  4.2376e-21   4.71879e-21     4.71879e-21  4.2376e-21
#  ⋮                                      ⋱
#  4.07784e-21  4.2376e-21   4.71879e-21     4.71879e-21  4.2376e-21
#  3.37226e-21  3.50438e-21  3.90231e-21  …  3.90231e-21  3.50438e-21
#  2.76903e-21  2.87751e-21  3.20426e-21     3.20426e-21  2.87751e-21
#  2.2605e-21   2.34906e-21  2.6158e-21      2.6158e-21   2.34906e-21
#  1.8403e-21   1.9124e-21   2.12955e-21     2.12955e-21  1.9124e-21
#  1.50324e-21  1.56214e-21  1.73952e-21     1.73952e-21  1.56214e-21
#  1.24522e-21  1.294e-21    1.44094e-21  …  1.44094e-21  1.294e-21
#  1.0631e-21   1.10475e-21  1.23019e-21     1.23019e-21  1.10475e-21
#  9.54691e-22  9.92094e-22  1.10475e-21     1.10475e-21  9.92094e-22
# LatticeField{Intensity, Float64, 2}
# Lattice: (-15.890625:0.25:15.859375, -15.890625:0.25:15.859375)

# %%
p7 = look(dsbeam0, LF0out, dstarget, phi1, LFout)
# Out:
# 128×640 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(4.10795e-5)   …  Gray{Float64}(9.86317e-10)
#  Gray{Float64}(4.80944e-5)      Gray{Float64}(9.83829e-10)
#  Gray{Float64}(5.61666e-5)      Gray{Float64}(9.86517e-10)
#  Gray{Float64}(6.54299e-5)      Gray{Float64}(9.94475e-10)
#  Gray{Float64}(7.60306e-5)      Gray{Float64}(1.0079e-9)
#  Gray{Float64}(8.81281e-5)   …  Gray{Float64}(1.02712e-9)
#  Gray{Float64}(0.000101895)     Gray{Float64}(1.05256e-9)
#  Gray{Float64}(0.000117519)     Gray{Float64}(1.08484e-9)
#  Gray{Float64}(0.000135201)     Gray{Float64}(1.12472e-9)
#  Gray{Float64}(0.000155154)     Gray{Float64}(1.1732e-9)
#  ⋮                           ⋱
#  Gray{Float64}(0.000137566)     Gray{Float64}(1.28049e-9)
#  Gray{Float64}(0.000119613)  …  Gray{Float64}(1.21681e-9)
#  Gray{Float64}(0.000103743)     Gray{Float64}(1.16301e-9)
#  Gray{Float64}(8.9754e-5)       Gray{Float64}(1.11785e-9)
#  Gray{Float64}(7.74575e-5)      Gray{Float64}(1.08035e-9)
#  Gray{Float64}(6.66787e-5)      Gray{Float64}(1.04974e-9)
#  Gray{Float64}(5.72565e-5)   …  Gray{Float64}(1.02543e-9)
#  Gray{Float64}(4.9043e-5)       Gray{Float64}(1.00696e-9)
#  Gray{Float64}(4.19028e-5)      Gray{Float64}(9.93989e-10)

# %%
phi2 = upsample(phi1, 8);
beam_out_big = sft(sqrt.(beam0.data) .* exp.(2pi * im * phi2.data)) .^ 2|> nabs;
beam0_out_big = sft(sqrt.(beam0.data) .* exp.(0*2pi * im * phi2.data)) .^ 2 |> nabs;
LF0_out_big = LatticeField{Intensity}(beam0_out_big, beam0.L);
LF_out_big = LatticeField{Intensity}(beam_out_big, beam0.L);
p7 = look(LF0_out_big,phi2, LF_out_big)
# Out:
# 1024×3072 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(2.37343e-25)  …  Gray{Float64}(3.33542e-13)
#  Gray{Float64}(2.37349e-25)     Gray{Float64}(3.33349e-13)
#  Gray{Float64}(2.37363e-25)     Gray{Float64}(3.32673e-13)
#  Gray{Float64}(2.37385e-25)     Gray{Float64}(3.31515e-13)
#  Gray{Float64}(2.37417e-25)     Gray{Float64}(3.2988e-13)
#  Gray{Float64}(2.37457e-25)  …  Gray{Float64}(3.27773e-13)
#  Gray{Float64}(2.37506e-25)     Gray{Float64}(3.25201e-13)
#  Gray{Float64}(2.37564e-25)     Gray{Float64}(3.22174e-13)
#  Gray{Float64}(2.37631e-25)     Gray{Float64}(3.187e-13)
#  Gray{Float64}(2.37707e-25)     Gray{Float64}(3.14793e-13)
#  ⋮                           ⋱
#  Gray{Float64}(2.37707e-25)  …  Gray{Float64}(3.13899e-13)
#  Gray{Float64}(2.37631e-25)     Gray{Float64}(3.17906e-13)
#  Gray{Float64}(2.37564e-25)     Gray{Float64}(3.21479e-13)
#  Gray{Float64}(2.37506e-25)     Gray{Float64}(3.24605e-13)
#  Gray{Float64}(2.37457e-25)     Gray{Float64}(3.27276e-13)
#  Gray{Float64}(2.37417e-25)  …  Gray{Float64}(3.29483e-13)
#  Gray{Float64}(2.37385e-25)     Gray{Float64}(3.31217e-13)
#  Gray{Float64}(2.37363e-25)     Gray{Float64}(3.32474e-13)
#  Gray{Float64}(2.3735e-25)      Gray{Float64}(3.3325e-13)

# %%
plot(beam0_out_big[513,500:524])

# %%
plot(beam0_out[63,60:68])

# %%
phi = phi2.data
# phi.+= 2 * pi
phiout = convert(Matrix{Int64},floor.(((phi.+abs(minimum(phi))) .% (2 * pi) .+ 0.0).*256/(2*pi)))
minimum(phiout), maximum(phiout)

# %%
using Plots
plot(beam0.L[1],beam0.data[513,:])
# Out:
# UndefVarError: `beam0` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ z:\home\Vandy\code\julia\SLMTools\optimal_transport_example copy.ipynb:2
