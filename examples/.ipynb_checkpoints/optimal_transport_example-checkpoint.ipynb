# %%
using SLMTools, Images, Statistics,Plots
N = 1024
NSLM = 1024
gauss = makeGaussian((N, N), 5)
mu0=gauss .^ 2
mu = downsample(gauss .^ 2, 8) # Make a 8x downsampled image
mu ./= sum(mu) # Normalize by total intensity
p1=plotBeamMap(mu)

# %%
tw = 500 # size of target feature
NT = 1024
word = "S"
txt = hcat([makeLetter(i, (tw, tw))[:, (i == 'I' ? (floor(Int, 0.35 * tw):floor(Int, 0.65 * tw)) : (floor(Int, 0.2 * tw):floor(Int, 0.85 * tw)))] for i in word]...)
arr = zeros(typeof(txt[1]), NT, NT)
arr[CartesianIndices(size(txt)).+CartesianIndex((size(arr) .- size(txt)) .÷ 2).+0*CartesianIndex(N ÷ 4, 0)] .= txt
arr = imfilter(arr, Kernel.gaussian(10))
# Out:
# 1024×1024 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(9.50799e-18)  …  Gray{Float64}(1.75315e-17)
#  Gray{Float64}(9.40706e-18)     Gray{Float64}(1.69772e-17)
#  Gray{Float64}(9.36045e-18)     Gray{Float64}(1.6345e-17)
#  Gray{Float64}(9.36131e-18)     Gray{Float64}(1.5639e-17)
#  Gray{Float64}(9.42888e-18)     Gray{Float64}(1.48251e-17)
#  Gray{Float64}(9.60374e-18)  …  Gray{Float64}(1.39105e-17)
#  Gray{Float64}(9.86501e-18)     Gray{Float64}(1.29094e-17)
#  Gray{Float64}(1.02418e-17)     Gray{Float64}(1.18114e-17)
#  Gray{Float64}(1.07533e-17)     Gray{Float64}(1.06362e-17)
#  Gray{Float64}(1.13966e-17)     Gray{Float64}(9.39121e-18)
#  ⋮                           ⋱
#  Gray{Float64}(3.23546e-17)  …  Gray{Float64}(2.82917e-17)
#  Gray{Float64}(3.31749e-17)     Gray{Float64}(2.87457e-17)
#  Gray{Float64}(3.39422e-17)     Gray{Float64}(2.90994e-17)
#  Gray{Float64}(3.46946e-17)     Gray{Float64}(2.93651e-17)
#  Gray{Float64}(3.54345e-17)     Gray{Float64}(2.95448e-17)
#  Gray{Float64}(3.61584e-17)  …  Gray{Float64}(2.96406e-17)
#  Gray{Float64}(3.68809e-17)     Gray{Float64}(2.96519e-17)
#  Gray{Float64}(3.76027e-17)     Gray{Float64}(2.95726e-17)
#  Gray{Float64}(3.8308e-17)      Gray{Float64}(2.94266e-17)

# %%
v = downsample(arr, 8; reducer=mean) |> itfa
v ./= sum(v)
L = natlat((128, 128))
phi1 = OTphase(mu, L, v, L, 0.001)
mu_new = sft(sqrt.(mu) .* exp.(2pi * im * phi1)) .^ 2 |> nabs
p2 = hm(mu_new)

# %%
slm_bitmap=Int.(floor.(ramp.((phi1.*256) .% 256)))
println(slm_bitmap |> maximum)
slm_bitmap |> minimum
# Out:
# 255
# 0

# %%
minimum(phi1)
# Out:
# -0.019099886402194954
