# %%
using SLMTools
linImgs, linImgNames = getImagesAndFilenames("test_data/test_images_B/LinearPhases/", ".bmp")
# Out:
# (Matrix{ColorTypes.RGB{FixedPointNumbers.N0f8}}[[RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004) … RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004); RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004) … RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004); … ; RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0) … RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0); RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0) … RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0)], [RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004) … RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004); RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004) … RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004); … ; RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0) … RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0); RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0) … RGB{N0f8}(0.0,0.0,0.0) RGB{N0f8}(0.0,0.0,0.0)], [RGB{N0f8}(0.004,0.004,0.004) RGB{N0f8}(0.004,0.004,0.004) … RGB{N0f8}(0.004,0.004
# ...

# %%
cd("../")
pwd()
# Out:
# "z:\\home\\Vandy\\code\\julia\\SLMTools"
